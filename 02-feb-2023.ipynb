# %%
import pandas as pd
import numpy as np
data = pd.read_csv("netflix_titles_2021 (3).csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.value_counts()
# Out:
# show_id  type   title                director             cast                                                                                                                                                                           country                                                 date_added          release_year  rating  duration  listed_in                                         description
# s10      Movie  The Starling         Theodore Melfi       Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor         United States                                           September 24, 2021  2021          PG-13   104 min   Comedies, Dramas                                  A woman adjusting to life after a loss contends with a feisty bird that's taken over her garden — and a husband who's struggling to find a way forward.     1
# ...

# %%
data.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
data.country.value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.sort_values(by = "cast")
# Out:
#      show_id     type                                      title  \
# 2102   s2103  TV Show                           Ojos in d' House
# 5997   s5998    Movie                         2015 Dream Concert
# 7985   s7986    Movie                                     Set Up
# 5761   s5762    Movie  LEGO Jurassic World: The Indominus Escape
# 7662   s7663    Movie    One Heart: The A.R. Rahman Concert Film
# ...      ...      ...                                        ...
# 8746   s8747    Movie                                     Winnie
# 8755   s8756  TV Show                          Women Behind Bars
# 8756   s8757    Movie                                  Woodstock
# 8763   s8764    Movie            WWII: Report from the Aleutians
# 8803   s8804  TV Show                                Zombie Dumb
#
#               director                                               cast  \
# 2102               NaN  'Najite Dede, Jude Chukwuka, Taiwo Arimoro, Od...
# ...

# %%
data.release_year.min()
# Out:
# 1925

# %%
data.release_year.max()
# Out:
# 2021

# %%
data.release_year.std()
# Out:
# 8.819312130834057

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.sort_values(by = "release_year", inplace = True)
data.head()
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4250                          NaN                        NaN            NaN
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
#
#              date_added  release_year rating  duration  \
# ...

# %%
data.sort_values(by = "release_year",ascending= False, inplace = True)
data.head(30)
# Out:
#      show_id     type                               title            director  \
# 965     s966  TV Show                              Yasuke                 NaN
# 882     s883    Movie              Jungle Beat: The Movie         Brent Dawes
# 870     s871    Movie          Amy Tan: Unintended Memoir       James Redford
# 1460   s1461  TV Show                             Monarca                 NaN
# 876     s877  TV Show                        Alma Matters                 NaN
# 857     s858  TV Show                        The Neighbor                 NaN
# 861     s862    Movie  Little Singham Future mein Satakli       Prakash Satam
# 862     s863  TV Show                             Special                 NaN
# 869     s870  TV Show                    Who Killed Sara?                 NaN
# 871     s872    Movie                  Sardar Ka Grandson       Kaashvie Nair
# 880     s881  TV Show                             Haunted                 NaN
# ...

# %% [markdown]
# # creating Data Frame

# %%
car = {"brand":["audi","Tata","VOLVO"],"price":[10,50,25]}
df =pd.DataFrame(car)
df.head()
# Out:
#    brand  price
# 0   audi     10
# 1   Tata     50
# 2  VOLVO     25

# %%
dic = {"student Name":["abhimanyu Ravi C R ","Ajith","Akshay A ","Alen Tom Shaji","anand amal","Ansal M T","Arun kumar ","aswin","Dhavood Nassar","Haripriya K u","Indrajith","jishanu v s","jishnu raj mp","jopika","keerthi ravi","kiran k s","Lubina nizar","Mancy mamachan","merlin pm","muhammed safeer","mohammed siraj","nanadankrishana N","Najmi jahangir","Nida mustafa","rahul N","ramshad","sanika sajeev","Sanoy K m","Shammas n m","smijith","sneha shaji","soorya","swathi","vidhya","vishnu mukundan"],
       "python":[24,25,24,25,25,25,24,24,24,24,25,25,23,24,25,24,24,25,24,24,24,0,25,25,25,25,25,24,24,24,22,24,25,23,24],
       "staticstics":[15,15,18,18,16,19,15,13,16,17,13,15,15,13,16,20,16,16,16,15,19,0,13,15,16,19,17,15,17,13,13,16,16,17,17],
       "Total":[39,40,42,43,41,44,39,37,40,41,38,40,38,37,41,44,40,41,40,39,43,0,38,40,41,44,42,39,41,37,35,40,41,40,41],
       "percentage":[86.67,88.89,93.33,95.56,91.11,97.78,86.67,82.22,88.89,91.11,84.44,88.89,84.44,82.22,91.11,97.78,88.89,91.11,88.89,86.67,95.56,0,84.44,88.89,91.11,97.78,93.33,86.67,91.11,82.22,77.78,88.89,91.11,88.89,91.11]}
df1 = pd.DataFrame(dic)
df1.head()
# Out:
#           student Name  python  staticstics  Total  percentage
# 0  abhimanyu Ravi C R       24           15     39       86.67
# 1                Ajith      25           15     40       88.89
# 2            Akshay A       24           18     42       93.33
# 3       Alen Tom Shaji      25           18     43       95.56
# 4           anand amal      25           16     41       91.11

# %%
list1 = ["abhimanyu Ravi C R ","Ajith","Akshay A ","Alen Tom Shaji","anand amal","Ansal M T","Arun kumar ","aswin","Dhavood Nassar","Haripriya K u","Indrajith","jishanu v s","jishnu raj mp","jopika","keerthi ravi","kiran k s","Lubina nizar","Mancy mamachan","merlin pm","muhammed safeer","mohammed siraj","nanadankrishana N","Najmi jahangir","Nida mustafa","rahul N","ramshad","sanika sajeev","Sanoy K m","Shammas n m","smijith","sneha shaji","soorya","swathi","vidhya","vishnu mukundan"]
len(list1)
# Out:
# 34

# %%
df1
# Out:
#            student Name  python  staticstics  Total  percentage
# 0   abhimanyu Ravi C R       24           15     39       86.67
# 1                 Ajith      25           15     40       88.89
# 2             Akshay A       24           18     42       93.33
# 3        Alen Tom Shaji      25           18     43       95.56
# 4            anand amal      25           16     41       91.11
# 5             Ansal M T      25           19     44       97.78
# 6           Arun kumar       24           15     39       86.67
# 7                 aswin      24           13     37       82.22
# 8        Dhavood Nassar      24           16     40       88.89
# 9         Haripriya K u      24           17     41       91.11
# 10            Indrajith      25           13     38       84.44
# 11          jishanu v s      25           15     40       88.89
# 12        jishnu raj mp      23           15     38       84.44
# 13               jopika      24           13     37       82.22
# ...

# %%
df1.tail()
# Out:
#        student Name  python  staticstics  Total  percentage
# 30      sneha shaji      22           13     35       77.78
# 31           soorya      24           16     40       88.89
# 32           swathi      25           16     41       91.11
# 33           vidhya      23           17     40       88.89
# 34  vishnu mukundan      24           17     41       91.11

# %%
df1.sample()
# Out:
#   student Name  python  staticstics  Total  percentage
# 5    Ansal M T      25           19     44       97.78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   3 non-null      object
#  1   price   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df1.python.min()
# Out:
# 0

# %%
df1.max()
# Out:
# student Name    vishnu mukundan
# python                       25
# staticstics                  20
# Total                        44
# percentage                97.78
# dtype: object

# %%
df1.describe()
# Out:
#           python  staticstics      Total  percentage
# count  35.000000    35.000000  35.000000   35.000000
# mean   23.600000    15.428571  39.028571   86.730286
# std     4.167098     3.265557   7.106276   15.791963
# min     0.000000     0.000000   0.000000    0.000000
# 25%    24.000000    15.000000  39.000000   86.670000
# 50%    24.000000    16.000000  40.000000   88.890000
# 75%    25.000000    17.000000  41.000000   91.110000
# max    25.000000    20.000000  44.000000   97.780000

# %%
df1.sort_values(by="python",)
