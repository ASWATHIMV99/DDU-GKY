# %%
import pandas as pd
import numpy as numpy
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('./Car_sales_dataset.csv')

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919             16.360    Passenger
# 1        Acura       TL              39.384             19.875    Passenger
# 3        Acura       RL               8.588             29.725    Passenger
# 4         Audi       A4              20.397             22.255    Passenger
# 5         Audi       A6              18.780             23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %%
data.dropna(inplace= True)
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.rename(columns={'__year_resale_value' : 'year_resale_value'}, inplace=True)
data.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919             16.360    Passenger
# 1        Acura       TL              39.384             19.875    Passenger
# 3        Acura       RL               8.588             29.725    Passenger
# 4         Audi       A4              20.397             22.255    Passenger
# 5         Audi       A6              18.780             23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.describe().T
# Out:
#                     count        mean        std         min         25%  \
# Sales_in_thousands  117.0   59.112316  75.058933    0.110000   16.767000
# year_resale_value   117.0   18.031538  11.605632    5.160000   11.240000
# Price_in_thousands  117.0   25.969487  14.149699    9.235000   16.980000
# Engine_size         117.0    3.048718   1.055169    1.000000    2.200000
# Horsepower          117.0  181.282051  58.591786   55.000000  140.000000
# Wheelbase           117.0  107.326496   8.050588   92.600000  102.400000
# Width               117.0   71.189744   3.530151   62.600000   68.500000
# Length              117.0  187.717949  13.849926  149.400000  177.500000
# Curb_weight         117.0    3.324051   0.597177    1.895000    2.911000
# Fuel_capacity       117.0   17.812821   3.794609   10.300000   15.300000
# Fuel_efficiency     117.0   24.119658   4.404470   15.000000   22.000000
# Power_perf_factor   117.0   74.930921  25.771796   23.276272   55.297117
#
# ...

# %% [markdown]
# ## Plot on numerical value columns

# %% [markdown]
# ### HISTOGRAM

# %%
data.Horsepower.plot.hist(figsize=(6,3), cmap='brg');

# %%
data.year_resale_value.plot.hist(figsize=(6,3), cmap='rainbow');

# %% [markdown]
# ## BOXPLOT

# %%
data.Sales_in_thousands.plot.box(figsize=(7,3), cmap='magma')
# Out:
# <AxesSubplot: >

# %%
data.Width.plot.box(figsize=(6,2), cmap= 'rainbow')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## SUBPLOT

# %%
data.plot.box(figsize=(20,3), subplots= True);

# %%
data.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
data.plot.hist(figsize=(6,18),subplots = True);

# %%
data.sort_values(by='year_resale_value').plot.line('year_resale_value','Price_in_thousands' , figsize=(6,3), cmap='inferno');

# %% [markdown]
# ## BAR PLOT

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(6,2), cmap='rainbow');

# %%
data.Model.value_counts().plot.bar(figsize=(19,3), cmap='rainbow');

# %%
data.sort_values(by='Price_in_thousands')[:20].plot.bar('Manufacturer','Price_in_thousands' , figsize=(6,3));

# %% [markdown]
# ## AREA CHART

# %%
data.plot.area('Manufacturer','Price_in_thousands' , figsize=(6,3), cmap='inferno')
# Out:
# <AxesSubplot: xlabel='Manufacturer'>

# %% [markdown]
# ## HORIZONTAL BAR CHART

# %%
data.Manufacturer.value_counts()[:5].plot.barh(figsize=(4,4), cmap='inferno');

# %%
data.sort_values(by= 'Price_in_thousands')[:15].plot.barh('Model','Fuel_capacity', figsize=(6,4));

# %% [markdown]
# ## SCATTER PLOT

# %%
data.plot.scatter('Fuel_efficiency','Fuel_capacity', figsize=(3,3));

# %%
data.sort_values(by='Latest_Launch') [0:20].plot.scatter('Width','Length', figsize=(5,2));

# %%
data.plot.box(figsize=(22,5));

# %%
data.sort_values(by='Engine_size', ascending=False)[0:10].Engine_size.plot.pie();

# %%
data.Manufacturer.value_counts().plot.pie(autopct= '%1.2f%%' );

# %%
data.groupby(['Manufacturer'] )['Sales_in_thousands'].mean().plot.pie(autopct="%1.1f%%");

# %% [markdown]
# # KDE PLOT

# %%
data.plot.kde(figsize = (15,6.2));

# %% [markdown]
# ## SUBPLOTS

# %%
data.plot.kde(figsize=(12,10), subplots= True);
