# %% [markdown]
# ### Pandas Basics

# %%
import pandas as pd

# %%
data = pd.read_csv("./titanic.csv")

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 1304   NaN      0      0           A.5. 3236    8.0500  ...        S  1227.0
# 1305  39.0      0      0            PC 17758  108.9000  ...        C   229.0
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500  ...        S  1169.0
# 1307   NaN      0      0              359309    8.0500  ...        S  1289.0
# 1308   NaN      1      1                2668   22.3583  ...        C   702.0
#
#                                  Name_wiki Age_wiki  \
# ...

# %%
data.sample()
# Out:
#       PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 1036         1037       NaN       3  Vander Planke, Mr. Julius  male  31.0
#
#       SibSp  Parch  Ticket  Fare  ... Embarked  WikiId  \
# 1036      3      0  345763  18.0  ...        S  1279.0
#
#                       Name_wiki Age_wiki            Hometown      Boarded  \
# 1036  Vanderplancke, Mr. Julius     31.0  Zwevezele, Belgium  Southampton
#
#             Destination Lifeboat Body Class
# 1036  Fremont, Ohio, US      NaN  NaN   3.0
#
# [1 rows x 21 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
data.shape
# Out:
# (1309, 21)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %% [markdown]
# ### Null percentage

# %%
data.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Lifeboat       61.650115
# Body           90.068755
# Class           0.381971
# dtype: float64

# %% [markdown]
# ### dropping the coloumns

# %%
data.drop(columns=['Body','Lifeboat','Cabin','PassengerId','WikiId','Name_wiki'] , inplace=True)
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
data.Embarked.fillna('S', inplace=True)
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Boarded.value_counts()
# Out:
# Southampton    916
# Cherbourg      259
# Queenstown     119
# Belfast         10
# Name: Boarded, dtype: int64

# %%
data.Boarded.fillna('Southampton', inplace=True)
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.Age.value_counts()
# Out:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %%
data.Age.fillna(24.0, inplace=True)
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          0
# Destination      5
# Class            5
# dtype: int64

# %%
data.Fare.value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 7.7417      1
# 8.1583      1
# 8.4583      1
# 7.8000      1
# 7.7208      1
# Name: Fare, Length: 281, dtype: int64

# %%
Fare_mean=data.Fare.mean()
Fare_mean
# Out:
# 33.2954792813456

# %%
data.Fare.fillna(Fare_mean, inplace=True)
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          0
# Destination      5
# Class            5
# dtype: int64

# %%
data.Destination.value_counts()
data.Destination.fillna("New York City", inplace=True)
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          0
# Destination      0
# Class            5
# dtype: int64

# %%
data.Age_wiki.value_counts()
mode_agewiki= data.Age_wiki.mode()
mode_agewiki
data.Age_wiki.fillna(mode_agewiki,inplace=True)
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          0
# Destination      0
# Class            5
# dtype: int64

# %%
data.Class.value_counts()
# Out:
# 3.0    706
# 1.0    326
# 2.0    272
# Name: Class, dtype: int64

# %%
class_mode=data.Class.mode()
class_mode

data.Class.fillna(3,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Hometown.value_counts()
# Out:
# New York, New York, US                70
# London, England                       49
# London, England, UK                   30
# Paris, France                         23
# Montreal, Quebec, Canada              20
#                                       ..
# Avaldsnes, Stavanger, Norway           1
# Marbella, Spain                        1
# Västermo, Södermanland, Sweden         1
# Trollhättan, Västergötland, Sweden     1
# Sar'al[81], Syria                      1
# Name: Hometown, Length: 566, dtype: int64

# %%
data.Hometown.fillna('New York, New York, US ' , inplace=True)
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Survived.fillna(0, inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Age_wiki       7
# Hometown       0
# Boarded        0
# Destination    0
# Class          0
# dtype: int64

# %% [markdown]
#  ### Group by and query

# %%
sex_survived = data.groupby(["Sex"])["Survived"].sum()

# %%
sex_survived
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %%
Pclass_Survived = data.groupby(["Pclass"])["Survived"].sum()
Pclass_Survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
Age_SibSp = data.groupby(["SibSp"])["Age"].value_counts()
Age_SibSp
# Out:
# SibSp  Age
# 0      24.0    238
#        22.0     35
#        21.0     33
#        30.0     30
#        18.0     26
#               ...
# 5      11.0      1
#        14.0      1
#        16.0      1
# 8      24.0      8
#        14.5      1
# Name: Age, Length: 223, dtype: int64

# %%
pclass_hometown= data.groupby(["Pclass"])["Hometown"].value_counts()
pclass_hometown
# Out:
# Pclass  Hometown
# 1       New York, New York, US            70
#         London, England, UK               19
#         Montreal, Quebec, Canada          15
#         Paris, France                     14
#         Philadelphia, Pennsylvania, US    12
#                                           ..
# 3       Youngstown, Ohio, US               1
#         Áyios Sóstis, Greece               1
#         Örsjö, Kalmar, Sweden              1
#         Östra Sallerup, Skåne, Sweden      1
#         Øyer, Norway                       1
# Name: Hometown, Length: 604, dtype: int64

# %% [markdown]
# ### query

# %%
BordedSouthampton = data.query("Boarded == 'Southampton'")

# %%
BordedSouthampton
# Out:
#       Survived  Pclass                                             Name  \
# 0          0.0       3                          Braund, Mr. Owen Harris
# 2          1.0       3                           Heikkinen, Miss. Laina
# 3          1.0       1     Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                         Allen, Mr. William Henry
# 6          0.0       1                          McCarthy, Mr. Timothy J
# ...        ...     ...                                              ...
# 1302       0.0       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       0.0       3                   Henriksson, Miss. Jenny Lovisa
# 1304       0.0       3                               Spector, Mr. Woolf
# 1306       0.0       3                     Saether, Mr. Simon Sivertsen
# 1307       0.0       3                              Ware, Mr. Frederick
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
Age_24 = data.query("Age == 24")
Age_24
# Out:
#       Survived  Pclass                             Name     Sex   Age  SibSp  \
# 5          0.0       3                 Moran, Mr. James    male  24.0      0
# 17         1.0       2     Williams, Mr. Charles Eugene    male  24.0      0
# 19         1.0       3          Masselmani, Mrs. Fatima  female  24.0      0
# 26         0.0       3          Emir, Mr. Farred Chehab    male  24.0      0
# 28         1.0       3    O'Dwyer, Miss. Ellen "Nellie"  female  24.0      0
# ...        ...     ...                              ...     ...   ...    ...
# 1299       0.0       3  Riordan, Miss. Johanna Hannah""  female  24.0      0
# 1301       0.0       3           Naughton, Miss. Hannah  female  24.0      0
# 1304       0.0       3               Spector, Mr. Woolf    male  24.0      0
# 1307       0.0       3              Ware, Mr. Frederick    male  24.0      0
# 1308       0.0       3         Peter, Master. Michael J    male  24.0      1
#
# ...

# %%
Agefem= Age_24.query("Sex == 'male'")
Agefem
# Out:
#       Survived  Pclass                            Name   Sex   Age  SibSp  \
# 5          0.0       3                Moran, Mr. James  male  24.0      0
# 17         1.0       2    Williams, Mr. Charles Eugene  male  24.0      0
# 26         0.0       3         Emir, Mr. Farred Chehab  male  24.0      0
# 29         0.0       3             Todoroff, Mr. Lalio  male  24.0      0
# 36         1.0       3                Mamee, Mr. Hanna  male  24.0      0
# ...        ...     ...                             ...   ...   ...    ...
# 1277       0.0       3  Aronsson, Mr. Ernst Axel Algot  male  24.0      0
# 1287       0.0       3            Colbert, Mr. Patrick  male  24.0      0
# 1304       0.0       3              Spector, Mr. Woolf  male  24.0      0
# 1307       0.0       3             Ware, Mr. Frederick  male  24.0      0
# 1308       0.0       3        Peter, Master. Michael J  male  24.0      1
#
#       Parch     Ticket     Fare Embarked  Age_wiki  \
# ...

# %%
PClass_1= data.query("Pclass==1")
PClass_1
# Out:
#       Survived  Pclass                                               Name  \
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6          0.0       1                            McCarthy, Mr. Timothy J
# 11         1.0       1                           Bonnell, Miss. Elizabeth
# 23         1.0       1                       Sloper, Mr. William Thompson
# ...        ...     ...                                                ...
# 1294       0.0       1                             Carrau, Mr. Jose Pedro
# 1295       0.0       1                       Frauenthal, Mr. Isaac Gerald
# 1298       0.0       1                         Widener, Mr. George Dunton
# 1302       0.0       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
#
#          Sex   Age  SibSp  Parch    Ticket      Fare Embarked  Age_wiki  \
# ...

# %%
Survived_1 = PClass_1.query("Survived == 1")
Survived_1
# Out:
#      Survived  Pclass                                               Name  \
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 11        1.0       1                           Bonnell, Miss. Elizabeth
# 23        1.0       1                       Sloper, Mr. William Thompson
# 31        1.0       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# ..        ...     ...                                                ...
# 862       1.0       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 871       1.0       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879       1.0       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887       1.0       1                       Graham, Miss. Margaret Edith
# 889       1.0       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Embarked  Age_wiki  \
# ...

# %% [markdown]
# asw = data.groupby(['Sex','Pclass'])['Embarked'].sum()
# asw
