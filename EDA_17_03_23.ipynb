# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('./insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#            count          mean           std        min       25%        50%  \
# age       1337.0     39.222139     14.044333    18.0000    27.000    39.0000
# bmi       1337.0     30.663452      6.100468    15.9600    26.290    30.4000
# children  1337.0      1.095737      1.205571     0.0000     0.000     1.0000
# charges   1337.0  13279.121487  12110.359656  1121.8739  4746.344  9386.1613
#
#                   75%          max
# age          51.00000     64.00000
# bmi          34.70000     53.13000
# children      2.00000      5.00000
# charges   16657.71745  63770.42801

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# ## EDA

# %% [markdown]
# # UNI VARIATE ANALYSIS

# %% [markdown]
# ### Hist plot

# %%
sns.histplot(df.children , color= 'black')
plt.show()

# %% [markdown]
# ### BOXPLOT

# %%
sns.boxplot('age', data=df)
plt.show()

# %% [markdown]
# # MULTI VARIATE ANALYSIS

# %% [markdown]
# ## COUNT PLOT

# %%
plt.figure(figsize=(40,9))
sns.countplot(x='age' ,data=df)
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.countplot(x= 'region',data= df)
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
plt.figure(figsize=(5,3))
sns.barplot(x='region', y='charges', hue='sex' , data=df, )
plt.show()

# %% [markdown]
# ## Line Plot

# %%
plt.figure(figsize= (5,3))
sns.lineplot(x= 'region', y= 'age', data=df ,hue='sex')
plt.show()

# %%
sns.lineplot('age','bmi', data = df)
plt.show()

# %% [markdown]
# ### Factor plolt

# %%
sns.set_style('ticks')
sns.factorplot('region','age', hue='sex', data=df)
plt.show()

# %% [markdown]
# ### PIE Chart

# %%
re_se =df.groupby(['region'])['charges'].sum()
re_se
# Out:
# region
# northeast    4.343669e+06
# northwest    4.034072e+06
# southeast    5.363690e+06
# southwest    4.012755e+06
# Name: charges, dtype: float64

# %%
sns.set_style('ticks')
re_se.plot.pie()
plt.legend( loc ='lower left')
plt.show()

# %% [markdown]
# ## PAIR PLOT

# %%
sns.pairplot(data= df, hue= 'sex')
plt.show()

# %%
heat_map= df.corr()
sns.heatmap(heat_map)
plt.show()

# %% [markdown]
# ### Violin plot

# %%
sns.set_style('dark')
sns.violinplot('sex','age', hue ='region', data= df)
plt.show()

# %% [markdown]
# ### DESCRIPTIVE METHOD

# %%
# Ask question and find the answers frm the dataset

# %%
#region where maximum amount of smokers present
# to find the answers lets sort the dataframe by only smokers, then take the count of region

# %%
smokerr = df.query("smoker == 'yes'")
smokerr.region.value_counts()
# Out:
# southeast    91
# northeast    67
# southwest    58
# northwest    58
# Name: region, dtype: int64

# %%
sns.lineplot('smoker','age', data = df)
plt.show()
